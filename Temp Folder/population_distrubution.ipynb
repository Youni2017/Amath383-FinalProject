# %%
import pandas as pd
import matplotlib.pyplot as plt

# Manually create the data
data = {
    "Age": list(range(101)) + [100],
    "Total": [
        1.09, 1.1, 1.08, 1.12, 1.14, 1.16, 1.19, 1.22, 1.23, 1.23, 1.22, 1.23, 1.23, 1.26,
        1.29, 1.33, 1.33, 1.31, 1.31, 1.31, 1.29, 1.29, 1.31, 1.31, 1.3, 1.3, 1.3, 1.3,
        1.32, 1.36, 1.38, 1.41, 1.43, 1.43, 1.39, 1.37, 1.35, 1.35, 1.35, 1.35, 1.31,
        1.33, 1.33, 1.31, 1.31, 1.25, 1.22, 1.2, 1.16, 1.18, 1.15, 1.17, 1.22, 1.3, 1.27,
        1.22, 1.19, 1.2, 1.21, 1.26, 1.29, 1.29, 1.29, 1.28, 1.26, 1.23, 1.22, 1.19, 1.14,
        1.1, 1.06, 1.02, 0.97, 0.93, 0.87, 0.85, 0.83, 0.86, 0.6, 0.58, 0.54, 0.54, 0.46,
        0.4, 0.36, 0.32, 0.29, 0.25, 0.23, 0.2, 0.16, 0.14, 0.12, 0.11, 0.09, 0.07, 0.06,
        0.04, 0.03, 0.03, 0.01, 0.03
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Grouping the data into age ranges
bins = list(range(0, 101, 10)) + [float('inf')]  # Create bins for age ranges: 0-10, 11-20, ..., 91-100+
labels = [f"{bins[i]}-{bins[i+1]-1}" for i in range(len(bins)-1)]
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Summing totals within each age group
grouped_data = df.groupby('Age Group')['Total'].sum()

# Plotting the distribution by age group
plt.figure(figsize=(12, 6))
grouped_data.plot(kind='bar', color='skyblue', edgecolor='black')

# Beautify the plot
plt.title('Age Group Distribution of Population', fontsize=16)
plt.xlabel('Age Group', fontsize=14)
plt.ylabel('Total (%)', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/rq/d1f380z1435dgk98n9b9hwz40000gn/T/ipykernel_36596/1372372546.py:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df.groupby('Age Group')['Total'].sum()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Manually create the data
data = {
    "Age": list(range(101)) + [100],
    "Total": [
        1.09, 1.1, 1.08, 1.12, 1.14, 1.16, 1.19, 1.22, 1.23, 1.23, 1.22, 1.23, 1.23, 1.26,
        1.29, 1.33, 1.33, 1.31, 1.31, 1.31, 1.29, 1.29, 1.31, 1.31, 1.3, 1.3, 1.3, 1.3,
        1.32, 1.36, 1.38, 1.41, 1.43, 1.43, 1.39, 1.37, 1.35, 1.35, 1.35, 1.35, 1.31,
        1.33, 1.33, 1.31, 1.31, 1.25, 1.22, 1.2, 1.16, 1.18, 1.15, 1.17, 1.22, 1.3, 1.27,
        1.22, 1.19, 1.2, 1.21, 1.26, 1.29, 1.29, 1.29, 1.28, 1.26, 1.23, 1.22, 1.19, 1.14,
        1.1, 1.06, 1.02, 0.97, 0.93, 0.87, 0.85, 0.83, 0.86, 0.6, 0.58, 0.54, 0.54, 0.46,
        0.4, 0.36, 0.32, 0.29, 0.25, 0.23, 0.2, 0.16, 0.14, 0.12, 0.11, 0.09, 0.07, 0.06,
        0.04, 0.03, 0.03, 0.01, 0.03
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting the line chart
plt.figure(figsize=(12, 6))
plt.plot(df['Age'], df['Total'], marker='o', label='Population Distribution')

# Beautify the plot
plt.title('Age Distribution of Population', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Total (%)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)
plt.tight_layout()

# Show the plot
plt.show()
